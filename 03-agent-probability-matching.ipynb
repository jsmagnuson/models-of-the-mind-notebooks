# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## <font color='red'>LAB REPORT</font>
#
# Answer the questions in Lab report parts 1-3 below (part 4 is the challenge section). It works best to copy and paste the questions into your report and insert your answers below each prompt. Remember, submit a 'static' file (.txt, .rtf, .doc, .pdf, etc.) and not a dynamic document link (e.g., to google docs). Make sure to include your name, date, and topic at the top of your report ('03: Agent-based probability matching').
#
# </div>

# %% [markdown]
# # PROBABILITY MATCHING, PART 3: an agent-based model
#
# ### Recapping the mathematical model approach
#
# Gallistel (1990) makes a compelling case that we *can* model probability matching in groups of foraging animals by assuming each animal represents the full complexity of the situation. That is, on Gallistel's *representational* theory, each duck (in our example domain) represents rate and magnitude of food available at each source and integrates those over time to assess the prevalence of food (size units per unit of time, e.g., $grams/minute$, although we do not assume the ducks have such specific units; in other parts of the book, Gallistel elegantly delves into how animals can represent time, rate, and magnitude [among other things] in a variety of domains). Once a duck has calculated (estimated) prevalence at each source, it needs to decide which source to go to. A simple way to do this is to consider each source's *share* of the total prevalence:
#
# $$
# share_1 = \frac{prevalence_1}{prevalence_1 + prevalence_2} \qquad\qquad share_2 = \frac{prevalence_2}{prevalence_1 + prevalence_2}
# $$
#
# With a 2:1 difference in prevalence, the shares are 2/3 and 1/3. Now, there is a hiccup: if every duck simply went to the source with the larger share, they would all end up at one source. Two things prevent that in our simulation. First, choice is *probabilistic*: when a duck decides, it picks each source with probability equal to that source's share, so with a 2:1 difference about 2/3 of the decisions favor the richer source. That is the **Luce choice rule** (Luce, 1959) in its original form -- the probability of choosing an option is its strength divided by the sum of the strengths of all the options -- with prevalence as the strength:
#
# $$
# P(\text{choose source 1}) = \frac{prevalence_1}{prevalence_1 + prevalence_2}
# $$
#
# (Notebook 02b used a common *variant* of the Luce rule in which each strength is first passed through an exponential, $e^{s \cdot prevalence}$, with switchiness $s$ as the exponent -- what machine learning calls a softmax. That nonlinearity is why the fit in 02b depended on the value of switchiness. Here we use the plain ratio form, which gives probability matching directly and frees switchiness to play a different role.) Second, ducks differ in *switchiness* -- how often they reconsider -- which is Gallistel's idea that animals vary in how willing they are to change patches.

# %% [markdown]
# ### Towards an Agent-Based approach
#
# Let's try modeling this system another way. Instead of devising equations that describe the system rather abstractly, let's see what it would take to simulate the moment-by-moment behavior of ducks.
#
# To do this, we are going to use **agent-based modeling**. This has some similarity to the cellular automata we played around with using the Game of Life simulator. But instead of our primitive elements only being fixed locations on a grid (although we did see the emergence of intercellular interactions that appeared to cohere and act as units), we are going to populate a grid with *agents* (ducks) that can navigate the grid (the pond).
#
# So let's think about all the things we have to define in order to create a simulation. (The values in parentheses are the defaults you will see on the sliders.)
#
# - Pond size and shape (let's keep it a rectangle, so we just have to define X and Y dimensions; 30 x 30 cells).
# - Food source dimensions -- let's put them at the top and bottom of the pond, but how big should they be? (Each source drops food into a strip across the middle 50% of the pond's width and 20% of its height, so 15 x 6 cells at the default pond size.)
# - Number of ducks (30).
# - Rates and morsel magnitudes (Source 1: a morsel of size 20 every 2 timesteps; Source 2: size 20 every 4 timesteps -- so Source 1 has twice the prevalence).
# - How ducks will update representations.
# - How many timesteps the simulation will last (200).
#
# Please review the code below -- at least skim it -- and read the description of how the simulation works. Then try the simulator and see if you can follow what the ducks are doing.
#
# ### How the simulation works
#
# **A timestep.** On each timestep the ducks take their turns one at a time, in a random order that is reshuffled every timestep; each duck follows the three rules below. When all the ducks have moved, each source drops a morsel if the timestep is a multiple of its rate (with the default rates, Source 1 drops on steps 2, 4, 6, ... and Source 2 on steps 4, 8, 12, ...). Then the prevalence estimate and the readouts are updated.
#
# **Why do the ducks take turns?**  A duck's move depends on which cells are free and whether a morsel is still there, so if all ducks acted at once from the same view of the pond, several could pick the same cell or the same morsel. Letting them act one at a time, in a fresh random order each step, resolves those conflicts automatically and gives no duck a permanent first pick, and *approximates* real-time, synchronous updating. Real ducks act at the same time, so this is an approximation; it could be made simultaneous, but then the tie-breaking rules have to be written explicitly (challenge question 19).
#
# **The rules each duck follows on its turn.** The rules are the same in both modes; the only difference is the part in brackets, which applies only in Representational mode (in Nonrepresentational mode a duck has no preferred source).
#
# 1. *Decide preferred source.* [Representational mode only.] With probability given by its personal *switchiness* value (a percent chance per timestep, set by the two switchiness sliders; see *Switchiness* below), the duck reconsiders its preferred source. When it does, it *stochastically* picks a source with probability equal to that source's share of the food dropped so far (its relative prevalence). It uses the *Luce Choice Rule* to choose, which avoids always choosing the source with higher prevalence. With a 2:1 ratio, for example, the richer source is chosen 2/3 of the time. If it picks the source it already prefers, nothing changes. Over many decisions, the proportion of ducks preferring each source comes to match the relative prevalence, no matter how *switchy* the ducks are (see *Switchiness* below).
# 2. *Aim.* The duck aims at the nearest morsel of food [at its preferred source] -- nearest by straight-line distance -- and moves one cell toward it: it moves to whichever of the eight adjacent cells is unoccupied and closest to the morsel. If the morsel itself is in an adjacent cell, the duck moves onto it and begins to eat it.
# 3. *Otherwise wander.* If there is no food to go to [at its preferred source], the duck moves to a random adjacent unoccupied cell. If all eight adjacent cells are occupied, it stays where it is. (With the optional 'Keep heading' rule turned on, it instead keeps going the way it was last heading when there was food available -- see the *Keep heading* check box in the tour of the window below.)
#
# **Rules that apply throughout.**
#
# - *One duck per cell.* Ducks never share a cell. A duck only ever moves into an unoccupied cell (or onto a morsel, which it then eats), so if the cell it would like is taken it goes to the best free cell instead, and if none of its eight neighbors is free it does not move. This is what makes crowding matter: near a busy source, ducks block each other, and a duck at the back of the crowd may not be able to get closer to food it can see.
# - *Eating takes time.* A duck that eats a morsel stays where it is, without moving or reconsidering, for 10 timesteps (or for *size* timesteps if 'Food takes time' is on); it turns red and fades to white while it eats, then goes back to its normal color. Only one duck gets each morsel -- the first to reach it.
# - *Moving.* One cell per timestep, in any of the eight directions. The pond has edges; ducks cannot wrap around.
# - *What the ducks know.* Every duck sees the whole pond: the nearest morsel [at its preferred source] wherever it is, with no limit on distance. In Representational mode every duck also knows the same prevalence: each source's share of all the food *mass* dropped so far (that is, rate x size, as in Gallistel), whether or not it ate any of it. Both are simplifications -- the ducks are, in effect, perfect observers of the food drops -- and they correspond to the assumption in Gallistel's account that animals go by what they observe, not by what they obtain. In the same spirit, every duck *sees* every morsel that was on the pond at the start of the timestep, even one that another duck gets first: a duck that saw a morsel land [at its preferred source] but has nothing to go to turns toward where it was. That only matters when 'Keep heading' is on, since that is the only rule that uses the heading.
# - *Where food lands.* Each drop is one morsel, placed in a random unoccupied cell in that source's 'drop zone' (the middle *Food % Width* of the pond, and *Food % Height* of the pond from the top for Source 1 or the bottom for Source 2). Morsels 'float' in their dropped location until eaten.
# - *Starting conditions.* Ducks start in random cells anywhere on the pond, [half of them preferring each source at random in Representational mode], and each duck is given its switchiness once, when it is created (changing switchiness during a simulation has no effect). So a run always starts near 50:50 and takes time to sort itself out.
#
# **Switchiness: how it works here.** A duck's *switchiness* is its chance, on any one timestep, of (re)determining its preferred food source [in Representational mode, of course]. The **Switchiness mean** slider sets the average of that chance across the flock, as a percentage. At the default of 5, a typical duck has a 5% chance of re-choosing on each timestep, which works out to re-choosing about once every 20 timesteps (100/5); at 50 it rethinks about every other timestep; at 99 (the max) almost every timestep; and at 1 (the min), about once in 100 timesteps. The **Switchiness standard deviation** slider (also in percent) spreads the ducks out around that mean: when the flock is created, each duck draws its own switchiness from a normal distribution with the mean and standard deviation you set (so with the defaults of 5 and 2, most ducks land between about 1 and 9, and some rethink several times as often as others). A duck keeps that number for the whole run, which is why the two sliders only take effect at Restart. Most of the time, then, a duck does not reconsider at all; it just carries on toward its current preferred source. When it does reconsider, it flips the weighted coin of Rule 1 (2/3 : 1/3 for a 2:1 prevalence) and may well re-pick the source it already had.
#
# Put those two pieces together and switchiness turns out to control only *how often* a duck changes its mind -- not *which way*. A duck with switchiness 50 (rethinking every other step) and a duck with switchiness 5 (rethinking every 20 steps) are equally likely to come down on the richer source each time they rethink (2/3), so over a long run both spend about 2/3 of their time preferring it. A switchy duck just changes its mind more often, in both directions. You can see this directly in the simulator: raising the switchiness mean makes the *midline crossings* increase faster, but leaves the *Duck preferences* readout where it was.
#
# Why do it this way? First, if every duck simply went to the denser source, the whole flock would end up at one source; probability matching needs the flock to *split* in proportion to the food, and letting each decision be a weighted coin flip is the simplest way to get that. Second, Gallistel's account says that animals differ in how readily they switch patches, and that this difference should not affect where they end up -- only how much they move around. Giving each duck its own switchiness, and making switchiness affect only how often it reconsiders, is our version of that.

# %% [markdown]
# **How this relates to Gallistel's equations, and where it departs from them.** This part is more technical; you can skip it if you are satisfied with the description so far. In Gallistel's model an animal's *affinity* for each patch is that patch's share of the observed prevalence, $A_1 = p_1/(p_1 + p_2)$ and $A_2 = p_2/(p_1 + p_2)$; it switches *to* each patch at a rate proportional to its affinity, $\lambda_1 = c A_1$ and $\lambda_2 = c A_2$; and $c = \lambda_1 + \lambda_2$, the animal's switchiness, varies from animal to animal. Our Rule 1 is the same thing in discrete time. Write $s$ for a duck's switchiness as a probability (the slider value divided by 100, so 0.05 at the default). The chance that a duck currently preferring source 2 switches to source 1 on a given step is $s A_1$ (reconsider, then pick source 1), and the chance of the reverse switch is $s A_2$, so $c$ is just $s$ in units of 'per timestep'. In either version, an animal at patch 1 leaves it at rate $\lambda_2$, so its stays there last $1/\lambda_2$ on average, and its stays at patch 2 last $1/\lambda_1$; the ratio of the two is $\lambda_1/\lambda_2 = A_1/A_2 = p_1/p_2$, whatever $c$ is. That is the mathematical form of the plain-language point above. Notebook 02b, by contrast, used the exponentiated (softmax) variant of the Luce rule with switchiness as the exponent, so there switchiness changed *which* split the ducks settled on and had to be tuned to get matching at all.
#
# Our simulation departs from Gallistel's equations in three ways worth noting:
#
# - *No gradual adjustment.* Gallistel's fourth assumption is that affinities adjust *gradually* when prevalences change. Our ducks use the current observed shares directly, so their affinities change in sync with changes in prevalence with delays that depend on various parameters.
# - *Perfect observers.* Gallistel's animal estimates prevalence from what it observes. Our ducks all share one exact prevalence, computed from every morsel dropped, which is the ideal case of that assumption. Of course, Gallistel's account also implies that all ducks have equal and full access to all information.
# - *Simulated ducks are embodied.* Gallistel's equations describe an animal that is simply 'at' one patch or the other. Our ducks have to move, and crossing the pond (at default size) takes about 20 timesteps -- about as long as a decision lasts at the default switchiness of 5. If ducks rethink much faster than they can travel, a duck that switches to the poorer source is likely to be switched back (with probability 2/3) before it ever gets there, while a duck heading for the richer source is usually re-confirmed (i.e., keeps that preference). Trips toward the poorer source tend to get aborted and trips toward the richer one do not, so the *positions* of the ducks become more extreme than their *preferences*, even though the preferences themselves still match. To get a sense of this, you could try raising the switchiness mean to 50 (and Restart) and compare the two readouts -- and see challenge question 17.
#
# ### Crucial test
#
# When you run the code cell below, a new window should open with the simulator. The simulation does not start until you press the play button (▶). If this does not happen, with or without an error message, please let me know. If there is an error message, please send that to me.

# %% [markdown]
# ### A tour of the simulator window
#
# <img src="image/duck_sim_example.jpg" width="900"/>
#
# *The simulator after a 200-step run with the default parameters (Representational mode, 'Keep heading' on).*
#
# **Left column.**
# - The **legend**: In Representational mode, ducks are dark blue if they currently prefer Source 1, or cyan if they prefer Source 2. In Nonrepresentational mode, they have no preference and are white; uneaten food is orange, and a duck that has just eaten turns red and fades to white while it 'eats', then goes back to its usual color.
# - The **pond**. Source 1 drops food into a zone at the top, Source 2 into a zone at the bottom (zones are defined by the Food % Height and Food % Width sliders); the black line is the midline, and a duck counts as 'nearer' the source on the same side of the midline as the duck.
# - Then we get 2 plots:
#     - The **upper plot** tracks 3 things over the run, all for Source 1: its share of the food dropped so far (red; this is the *prevalence* the ducks are matching, which is based on observed food dispersals rather than just defined based on parameter settings), the share of ducks that currently *prefer* it (dark blue; their internal state) and the share of ducks that are actually *nearer* it (black; the observable behavior). This is the same kind of plot as in notebook 02b. In the screenshot all three sit at about 2/3 by the end, which reflects probability matching.
#     - The **lower plot** tracks the number of untouched morsels floating on the pond (orange, like the food itself) and the number of ducks that crossed the midline during each timestep (green), both on the left axis, and the cumulative number of midline crossings (purple) on the right axis. These are quantities you may find useful to compare across parameter combinations.
#
# **Right column.**
# - **Control buttons at the top**: play/pause (the simulation does not start until you press play), Restart (new pond with the current settings; then press play), Continue (add another *Max Timesteps* steps to a finished run; you can click this more than once to set total desired simulations as multiples of 'Max Timesteps'), Repeat and graph (see below), and Quit. Pond height and width, the number of ducks, the two switchiness sliders, and the random seed only take effect when you click Restart; everything else takes effect immediately, even during a run. To go back to the default settings, close the window and re-run the code cell.
# - **Sliders** for the pond, the food, the ducks' switchiness (mean and standard deviation, as a percent chance per timestep of reconsidering), and the display, then the *Random seed* box and the *Graph repetitions* slider, then four **check boxes**: Representational, Food takes time, Keep heading, Show preference. *Food % Width* and *Food % Height* set each source's drop zone as a fraction of the pond (width 10-90%; height 10-50%, since 50% reaches the midline); a very small zone fills up with ducks, and morsels then land on occupied cells. *Image size* can be changed while a run is going; the pond is scaled down automatically if it would not fit on the screen.
#     - **Random seed**: put an integer here; then any time you run with the same parameters and that integer, you will get the same outcome. If you set it to 'None', no random seed is set and you will get different random properties every time you run a simulation.
#     - **Representational**: Set to 1 and we are in Representational mode; set to 0 we are in Nonrepresentational mode.
#     - **Food takes time**: When this is set to 0, food takes 10 steps to consume (if you want this to be a different value, you have to change it in the code currently). If you set it to 1, then food takes $S$ steps to consume, where $S$ is the Size value for that source.
#     - **Keep heading**: When set to 0: when there is no available (untouched) food in the system, ducks move to a random cell adjacent to their current cell (observing rules that prevent 2 ducks occupying the same cell). When set to 1, ducks continue moving in the direction of the last morsel of food they detected; if the cell ahead is blocked or off the pond, a duck sidesteps randomly but keeps its heading. The rule is the same in both modes and makes no reference to a preferred source -- it just gives ducks a little momentum. It matters when there are many ducks: with 200 ducks a morsel is eaten almost as soon as it lands, so most ducks spend most steps with no food in sight, and a random walk then drifts them toward 50:50 across the midline even when their *preferences* match prevalence; with this rule on, positions track preferences again. *To see the impact, set the number of ducks to 200 and run with default parameters, then run again with 'Keep heading' turned on. It won't be perfect in either case, but one definitely looks more plausible.* We can discuss which rule is more realistic, or whether we should have a different one.
#     - **Show preference**: For Representational mode, this toggles coloring ducks according to their preferences (blue = Source 1, cyan = Source 2); this has no effect on any results, it's just a graphical parameter.
# - **Readouts**, updated every timestep:
#     - *Food prevalence*: each source's share of all the food dropped so far -- what the ducks are supposed to match.
#     - *Ducks nearer*: the number and proportion of ducks in each half of the pond. This is the observable behavior, the equivalent of Harper counting the ducks in front of each thrower, and it is **the number to report in the lab**.
#     - *Duck preferences*: the proportion of ducks currently preferring each source (their internal state; only meaningful in Representational mode).
#     - *Discrepancy*: |Ducks nearer -- Food prevalence| for Source 1, the same definition as in notebook 02b.
#     - The current check-box settings.
#     - *Midline crossings*: the total so far and the number during the current timestep; *Untouched food count*: morsels floating uneaten right now.
#     - The yellow line: the current timestep, or a message (here, the files that the last *Repeat and graph* saved).
#
# ### Repeating simulations: the 'Repeat and graph' button
#
# A single run of 30 ducks can easily end up quite different from another run with identical settings (and a different random seed), just because of where the ducks happened to start and which morsels they happened to reach. We can get a better sense of the characteristics of a particular parameter combination by conducting  *repeated* runs. **Repeat and graph** runs a batch of simulations with the current settings -- as many as the *Graph repetitions* slider says (default 10), each with a different random seed (if you typed a seed, the runs use seed, seed+1, seed+2, ..., so the batch is reproducible) -- and then saves two files in a folder called `duck_runs` next to the notebook and opens the figure in a new window:
#
# <img src="image/duck_graph_example.jpg" width="900"/>
#
# *Ten runs with the default parameters. Lines are the mean across the runs; the shaded ribbons are plus or minus one standard error of the mean.*

# %% [markdown]
# - The **top panel** shows the same three series as the upper plot in the window, averaged over the runs, with error ribbons. Here the ducks' positions (black) start near 50:50 -- they were placed at random -- and move to the 2/3 : 1/3 split over the first 50 or so timesteps; the ribbons are narrow (about plus or minus 0.02), so ten runs pin the model's prediction down well.
# - **Why is the prevalence line (red) so jagged at first?** Because prevalence is not the *programmed* rate; it is computed from the food that has actually been dropped so far, which is also what the ducks are assumed to observe (Gallistel's point that animals go by what they see happen). At timestep 0 nothing has been dropped. At timestep 2 Source 1 drops its first morsel while Source 2 has dropped nothing, so Source 1's share is 1.0. At timestep 4 both have dropped one, so the share is 0.5; at 6 it is 2/3, at 8 it is 3/5, at 12 it is 2/3 again ... Each new morsel changes the totals less than the last one did, so the zigzag shrinks and the line converges on the programmed ratio of 2/3. Real ducks face the same thing: after a handful of throws, the observed ratio is a rough estimate, and it only becomes precise as the throws accumulate. This is also part of why the ducks in the simulation take a while to reach 2/3 -- early on they are matching an estimate that is itself jumping around.
# - The **bottom panel** shows untouched food (orange; the sawtooth is morsels landing every 2 and 4 timesteps and being eaten), midline crossings per timestep (green), and cumulative crossings (purple). The green line is highest in the first 20 or so timesteps, when the flock is sorting itself out, and then settles to a low, steady rate -- which is why the purple line is steep at first and then nearly straight. That early burst of crossings is the visible signature of the transient you see in the top panel.
#
# **The files.** Both are named from the parameters -- for example `ducks30_rate2-4_size20-20_sw5-2_rep1_ftt0_kh1_pond30x30_food50x20_T200_n10`, where `sw` is the switchiness mean and SD, `rep`, `ftt` and `kh` are the Representational, Food takes time and Keep heading settings, `T` is the number of timesteps and `n` the number of runs.
# - The `.png` is the figure.
# - The `.csv` has one row per run per timestep, with the columns `run, seed, timestep, nearer_source1, prefer_source1, prevalence_source1, untouched_food, midline_crossings, crossings_this_step` (the first three measures are proportions; `midline_crossings` is cumulative), and every parameter setting as `#` comment lines at the top. Pandas reads it with `pd.read_csv(path, comment='#')`, so you can make your own plots or analyses from it (see challenge question 18).
#
# While a batch runs, the controls are frozen so that the settings cannot change part way through, and the button turns into a Cancel button with an estimate of the time left. A batch of 10 takes about 10 times as long as a single run of the same length: roughly 30-40 seconds at the defaults, several minutes with 200 ducks.

# %%
# enable animation in jupyter 
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
import tkinter as tk
import random
import os
import csv
import time
import datetime


# Duck Agent
class Duck(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.color = "white"
        self.stay_time = 0
        self.initial_stay_time = 0
        self.heading = (0, 0)  # direction of the last move (dx, dy); (0, 0) = not moved yet
        # Switchiness: this duck's chance of reconsidering its source on any timestep. The
        # sliders are in percent; each duck draws its own value from a normal distribution
        # with that mean and SD, converted to a probability and clipped to 0-1.
        self.switchiness = max(0, min(1, random.gauss((sw_mean_slider.get()/100), (sw_sd_slider.get()/100))))
        self.preference = random.choice(['source1', 'source2'])  # Initial random preference
        self.color = self.preference_color()

    def preference_color(self):
        # Color of a duck that is not eating. With the 'Show preference' toggle on, it
        # shows the preferred source; otherwise (or with no preference, as in
        # Nonrepresentational mode) the duck is white.
        if show_preference_toggle.get() == 1:
            if self.preference == 'source1':
                return 'dark blue'
            elif self.preference == 'source2':
                return 'cyan'
        return 'white'


    def move_to(self, new_pos, toward=None):
        # Move toward food and remember the direction of the GOAL as the duck's heading
        # (a unit step: each of dx, dy is -1, 0, or 1). If the move was a detour around
        # an occupied cell, the heading is still the direction of the goal, not the detour.
        x, y = self.pos
        gx, gy = toward if toward is not None else new_pos
        self.heading = ((gx > x) - (gx < x), (gy > y) - (gy < y))
        self.model.grid.move_agent(self, new_pos)

    def update_midline_status(self):
        _, y = self.pos
        self.above_midline = y < self.model.grid.height // 2

    def distance(self, pos1, pos2):
        x1, y1 = pos1
        x2, y2 = pos2
        return ((x2 - x1)**2 + (y2 - y1)**2)**0.5
    
    def get_interpolated_color(self, start_color, end_color, proportion):
        # Unpack RGB values
        r1, g1, b1 = start_color
        r2, g2, b2 = end_color

        # Calculate interpolated RGB values (allows ducks to fade from red to pink to white while eating
        r = int(r1 + proportion * (r2 - r1))
        g = int(g1 + proportion * (g2 - g1))
        b = int(b1 + proportion * (b2 - b1))
    
        return f"#{r:02x}{g:02x}{b:02x}"

    def step(self):
         
        if self.stay_time > 0:
            # Calculate the proportion of stay_time remaining
            proportion = self.stay_time / self.initial_stay_time

            # Define the start and end colors in RGB
            end_color = (255, 50, 50)  # RGB for light red
            start_color = (255, 255, 255)  # RGB for white

            # Calculate the interpolated color
            self.color = self.get_interpolated_color(start_color, end_color, proportion)

            self.stay_time -= 1
            if self.stay_time == 0:
                self.color = self.preference_color()
            return       
        
            # failed code for putting a circle on eating ducks
            # dx, dy = self.pos
            # ox1, oy1 = dx * blocksize, dy * blocksize
            # ox2, oy2 = ox1 + blocksize, oy1 + blocksize
            # canvas.create_oval(ox1, oy1, ox2, oy2, fill="", outline="black")

        # get position
        x, y = self.pos
        # determine if you crossed the midline
        new_above_midline = y < self.model.grid.height // 2
    
        if self.above_midline != new_above_midline:
            self.model.midline_crossings += 1  # Increment the counter in the model

        self.above_midline = new_above_midline
        
        food_list = []  # food the duck can go to now (at its preferred source, or anywhere in Nonrepresentational mode)
        seen_list = []  # food that was there at the start of the step, whether or not it is still there
        relprev1 = self.model.relprev1
        relprev2 = self.model.relprev2

        if representational_toggle.get() == 1: # if this is 1 (True) then we are in representational mode
            # Decision-making based on relative prevalence.
            # Switchiness sets how OFTEN a duck reconsiders its preference; relative
            # prevalence sets WHICH source it picks when it does (Luce choice rule:
            # each source is chosen with probability equal to its share of the food).
            # Over many decisions the share of ducks preferring each source matches
            # relative prevalence, regardless of switchiness.
            if random.uniform(0, 1) < self.switchiness: # consider switching?
                if relprev1 != relprev2:
                    self.preference = 'source1' if random.uniform(0, 1) < relprev1 else 'source2'
                elif self.preference == 'either':
                    self.preference = random.choice(['source1', 'source2'])  # equal prevalence: choose randomly

            if self.preference == 'source1':
                food_list = [(agent, agent.pos) for agent in self.model.schedule.agents if isinstance(agent, Food) and agent.pos is not None and agent.pos[1] < self.model.grid.height // 2]
                seen_list = [(agent, pos) for agent, pos in self.model.food_positions if pos[1] < self.model.grid.height // 2]
            elif self.preference == 'source2':
                food_list = [(agent, agent.pos) for agent in self.model.schedule.agents if isinstance(agent, Food) and agent.pos is not None and agent.pos[1] > self.model.grid.height // 2]
                seen_list = [(agent, pos) for agent, pos in self.model.food_positions if pos[1] > self.model.grid.height // 2]
        else: # not in representational mode
            self.preference='either'
            # Get all food locations on the grid
            food_list = [(agent, agent.pos) for agent in self.model.schedule.agents if isinstance(agent, Food) and agent.pos is not None]
            seen_list = list(self.model.food_positions)

        #print(f'duck {self.unique_id}: relprev1 {relprev1} relprev2 {relprev2}, pref {self.preference}, color {self.color}')

        self.color = self.preference_color()
 

        # If there is food, find the closest one
        #print(food_list)
        if food_list:
            closest_food_pos = min(food_list, key=lambda x: self.distance(self.pos, x[1]))[1]

            # If the duck is right next to the closest food, move directly into that cell
            neighbors = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
            if closest_food_pos in neighbors:
                self.move_to(closest_food_pos)
                agents = self.model.grid.get_cell_list_contents([closest_food_pos])
                for agent in agents:
                    if isinstance(agent, Food):
                        self.color = "red"
                        if food_takes_time_toggle.get() == 1:
                            self.initial_stay_time = agent.size  # set initial stay_time which we will use to morph color
                            self.stay_time = agent.size
                        else:
                            self.initial_stay_time = 10  # set initial stay_time which we will use to morph color
                            self.stay_time = 10
                        self.model.grid.remove_agent(agent)
                        return

            # Otherwise, find the empty neighbor closest to the food and move there
            empty_neighbors = [pos for pos in neighbors if self.model.grid.is_cell_empty(pos)]
            if empty_neighbors:
                move_towards_food = min(empty_neighbors, key=lambda x: self.distance(closest_food_pos, x))
                self.move_to(move_towards_food, toward=closest_food_pos)

        else:
            # No food to go to right now (same rules in both modes).
            # PERCEPTION: a morsel that landed this step but was eaten before this duck's
            # turn was still SEEN. If one was seen, turn toward where it was. (Only the
            # 'Keep heading' rule below uses the heading, so this has no effect otherwise.)
            if seen_list:
                tx, ty = min(seen_list, key=lambda f: self.distance(self.pos, f[1]))[1]
                self.heading = ((tx > x) - (tx < x), (ty > y) - (ty < y))
            # OPTIONAL rule ('Keep heading if no food' toggle): keep going in the direction
            # you were last heading when you had food to aim at, so a duck that was on its
            # way to a morsel that got eaten carries on toward where it was. If the cell
            # ahead is off the pond or occupied, take a random sidestep but keep the
            # heading, so the duck hovers where the food was rather than wandering off.
            # DEFAULT rule: move to a random adjacent unoccupied cell.
            dx, dy = self.heading
            ahead = (x + dx, y + dy)
            if keep_heading_toggle.get() == 1 and (dx, dy) != (0, 0) \
                    and not self.model.grid.out_of_bounds(ahead) and self.model.grid.is_cell_empty(ahead):
                self.model.grid.move_agent(self, ahead)
            else:
                neighbors = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
                empty_neighbors = [pos for pos in neighbors if self.model.grid.is_cell_empty(pos)]
                if empty_neighbors:
                    # random steps do not change the heading; only aiming at food does
                    self.model.grid.move_agent(self, random.choice(empty_neighbors))

# Food Agent
class Food(Agent):
    def __init__(self, unique_id, model, size):
        super().__init__(unique_id, model)
        self.color = "orange"  # uneaten food; a duck that eats it turns red and fades to white
        self.size = size  

class DuckPond(Model):
    def __init__(self, width, height, nducks, seed=None):
        super().__init__(seed=seed)  # Initialize the Model class (seed sets the scheduler's random order)
        
        self.current_id = 0  # Add this line to initialize the ID counter
        
        self.num_agents = nducks
        
        #self.grid = MultiGrid(width, height, True)
        # Set torus to False so ducks can't 'wrap' from edges
        self.grid = MultiGrid(width, height, False)  
        
        self.midline_crossings = 0
        self.history = []  # per timestep: (nearer source 1, prefer source 1, prevalence source 1, untouched food, cumulative midline crossings, crossings this step)
        self._crossings_at_last_record = 0
 
        self.total_food_source1 = 0
        self.total_food_source2 = 0
        self.relprev1 = 0
        self.relprev2 = 0
        self.food_positions = []  # where food is at the start of the current step


        self.schedule = RandomActivation(self)
        self.rate1 = rate1_slider.get()
        self.rate2 = rate2_slider.get()

        # Initialize ducks
        for i in range(self.num_agents):
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            while not self.grid.is_cell_empty((x, y)):
                x = random.randrange(self.grid.width)
                y = random.randrange(self.grid.height)
            duck = Duck(self.next_id(), self)  # Use next_id() function here
            self.grid.place_agent(duck, (x, y))
            duck.update_midline_status()  
            self.schedule.add(duck)

        self.record_stats()  # timestep 0

    def step(self):
        self.rate1 = rate1_slider.get()
        self.rate2 = rate2_slider.get()
        # Snapshot of where the food is at the start of the step. Ducks move toward
        # food that is actually there, but every duck SEES the morsels that were there
        # at the start of the step, even the ones another duck gets first (Gallistel:
        # animals go by what they observe, not what they obtain).
        self.food_positions = [(agent, agent.pos) for agent in self.schedule.agents if isinstance(agent, Food) and agent.pos is not None]
        self.schedule.step()

        food_height = food_height_slider.get()
        use_food_height = int((food_height / 100) * height_slider.get())


        if self.schedule.time % self.rate1 == 0:
            self.add_food(0, use_food_height - 1, size1_slider.get())
            self.total_food_source1 += size1_slider.get()
            
        if self.schedule.time % self.rate2 == 0:
            self.add_food(self.grid.height - use_food_height, self.grid.height - 1, size2_slider.get())
            self.total_food_source2 += size2_slider.get()
            
        # Update prevalence
        prevalence1 = self.total_food_source1 / (self.schedule.time + 1)
        prevalence2 = self.total_food_source2 / (self.schedule.time + 1)

        if prevalence1 + prevalence2 != 0:
            self.relprev1 = prevalence1 / (prevalence1 + prevalence2)
            self.relprev2 = prevalence2 / (prevalence1 + prevalence2)
        else:
            self.relprev1 = 0
            self.relprev2 = 0

        self.record_stats()

    def record_stats(self):
        # Summary of the current state: where the ducks are, what they prefer, how much
        # food is floating. Stored in self.stats (for the readouts) and appended to
        # self.history (for the plots and for 'Repeat and graph'). Computed here, in the
        # model, so that a simulation can be run and measured without the window.
        mid = self.grid.height // 2
        nearer1 = nearer2 = pref1 = pref2 = food = 0
        for agent in self.schedule.agents:
            if agent.pos is None:
                continue
            if isinstance(agent, Duck):
                if agent.pos[1] < mid:
                    nearer1 += 1
                else:
                    nearer2 += 1
                if agent.preference == 'source1':
                    pref1 += 1
                elif agent.preference == 'source2':
                    pref2 += 1
            else:
                food += 1
        total_food = self.total_food_source1 + self.total_food_source2
        prev1 = self.total_food_source1 / total_food if total_food > 0 else 0
        prev2 = self.total_food_source2 / total_food if total_food > 0 else 0
        npref = pref1 + pref2
        step_crossings = self.midline_crossings - self._crossings_at_last_record  # crossings during this step
        self._crossings_at_last_record = self.midline_crossings
        self.stats = dict(nearer1=nearer1, nearer2=nearer2,
                          prop_nearer1=nearer1 / self.num_agents, prop_nearer2=nearer2 / self.num_agents,
                          prop_pref1=pref1 / npref if npref > 0 else 0, prop_pref2=pref2 / npref if npref > 0 else 0,
                          prev1=prev1, prev2=prev2, food=food, crossings=self.midline_crossings, step_crossings=step_crossings)
        self.history.append((self.stats['prop_nearer1'], self.stats['prop_pref1'], prev1, food, self.midline_crossings, step_crossings))

    def add_food(self, row_start, row_end, value):
        food_width = food_width_slider.get()        
        use_food_width = int((food_width / 100) * width_slider.get())
        half_width = use_food_width // 2  # Calculate half of the food_width
        start_col = int((self.grid.width // 2) - half_width)  # Calculate the starting column
        end_col = int((self.grid.width // 2) + half_width)  # Calculate the ending column

        x = random.randint(start_col, end_col)  # Randomly pick a column between start_col and end_col
        y = random.randint(row_start, row_end)  # Randomly pick a row between row_start and row_end

        tries = 0
        maxtries = 100
        while (not self.grid.is_cell_empty((x, y))) and tries < maxtries:
            x = random.randint(start_col, end_col)
            y = random.randint(row_start, row_end)
            tries += 1

        food = Food(self.next_id(), self, value)  # Create a new Food agent with the value
        self.grid.place_agent(food, (x, y))  # Place the Food agent on the grid
        self.schedule.add(food)  # Add the Food agent to the schedule
        
    def next_id(self):  # Add this function to generate the next ID
        self.current_id += 1
        return self.current_id

# The animation is a chain of root.after() callbacks. Exactly one chain runs at a
# time: schedule_update() cancels any pending callback before scheduling the next,
# so Restart/Continue cannot start a second, competing loop.
after_id = None

def schedule_update(delay):
    global after_id
    if after_id is not None:
        root.after_cancel(after_id)
    after_id = root.after(delay, update)

def continue_simulation():
    global max_timesteps
    max_timesteps += time_slider.get()  # allow this many more steps
    schedule_update(speed_slider.get())

def toggle_pause():
    global paused
    paused = not paused
    pause_button.config(text="\u25b6" if paused else "\u23f8")

def update():
    # (schedule_update cancels the previous callback, whether or not it has fired,
    # so update() is safe to call from the timer or directly)
    if paused:
        schedule_update(100)  # check again shortly
        return
    if model.schedule.time < max_timesteps:
        model.step()
        draw_pond()
        schedule_update(speed_slider.get())
    else:
        draw_pond(finished=True)

def quit_simulation():
    global after_id
    if after_id is not None:
        root.after_cancel(after_id)
        after_id = None
    root.destroy()

def get_seed():
    # Random seed from the entry box: blank or 'None' means a different run every time
    text = seed_entry.get().strip()
    if text == "" or text.lower() == "none":
        return None
    try:
        return int(text)
    except ValueError:
        return None

def new_model(seed=None):
    random.seed(seed)  # the ducks use the random module directly
    return DuckPond(width_slider.get(), height_slider.get(), duck_slider.get(), seed=seed)

def effective_blocksize():
    # Cell size in pixels: the Image size slider, capped so the pond fits on screen
    return max(2, min(blocksize_slider.get(), MAX_CANVAS_PX // max(model.grid.width, model.grid.height)))

def draw_pond(finished=False):
    # Redraw the pond. Water is the canvas background; only occupied cells are drawn,
    # so the cost scales with the number of ducks and morsels, not the pond area.
    blocksize = effective_blocksize()
    canvas_w = model.grid.width * blocksize
    canvas_h = model.grid.height * blocksize
    if int(canvas["width"]) != canvas_w or int(canvas["height"]) != canvas_h:
        canvas.config(width=canvas_w, height=canvas_h)  # Image size slider moved, or new pond
        plot.config(width=max(canvas_w, PLOT_MIN_W))
        plot2.config(width=max(canvas_w, PLOT_MIN_W))
    canvas.delete("all")

    midline = model.grid.height // 2
    for agent in model.schedule.agents:
        if agent.pos is None:
            continue
        x, y = agent.pos
        canvas.create_rectangle(x*blocksize, y*blocksize, x*blocksize+blocksize, y*blocksize+blocksize, fill=agent.color)

    # Gridlines, then the midline between the two halves of the pond
    for i in range(0, canvas_w + 1, blocksize):
        canvas.create_line(i, 0, i, canvas_h, fill="light grey")
    for i in range(0, canvas_h + 1, blocksize):
        canvas.create_line(0, i, canvas_w, i, fill="light grey")
    canvas.create_line(0, midline * blocksize, canvas_w, midline * blocksize, fill="black", width=2)

    # Readouts, from the statistics the model recorded at the end of its last step
    s = model.stats
    discrepancy = abs(s['prop_nearer1'] - s['prev1'])  # same definition as in notebook 02b
    label_food_prevalence.config(text=f"Food prevalence: source 1 = {s['prev1']:.3f}, source 2 = {s['prev2']:.3f}")
    label_ducks_nearer.config(text=f"Ducks nearer: source 1 = {s['nearer1']} ({s['prop_nearer1']:.3f}), source 2 = {s['nearer2']} ({s['prop_nearer2']:.3f})")
    label_duck_preference.config(text=f"Duck preferences: source 1 = {s['prop_pref1']:.3f}, source 2 = {s['prop_pref2']:.3f}")
    label_discrepancies.config(text=f"Discrepancy (source 1, |nearer - prevalence|): {discrepancy:.3f}")
    label_check_states.config(text=f"Representational: {representational_toggle.get()}   Food takes time: {food_takes_time_toggle.get()}   Keep heading if no food: {keep_heading_toggle.get()}   Show preference: {show_preference_toggle.get()}")
    label_ducks_crossed.config(text=f"Midline crossings: {s['crossings']} total, {s['step_crossings']} this step   Untouched food count: {s['food']}")
    status = f"Timestep: {model.schedule.time} of {max_timesteps}"
    if finished:
        status += "   -- finished; press Continue for more steps, or Restart"
    label_timestep.config(text=status)
    draw_plot()

def plot_axes(pc, n, left_max, right_max=None, left_color="black", right_color="black", top=22):
    # Axes box, gridlines and tick labels for a time-series plot. Returns the functions
    # that map a timestep to x and a value to y (one for the left axis and, if there is
    # a right axis, one for the right axis).
    w, h = int(pc["width"]), int(pc["height"])
    x0, x1, y0, y1 = 40, w - (44 if right_max is not None else 10), top, h - 22
    sx = lambda t: x0 + (x1 - x0) * t / max(n - 1, 1)
    def scaler(vmax):
        return lambda v: y1 - (y1 - y0) * v / vmax
    def ticks(vmax):
        # 0, midpoint, max -- as integers if the axis is a count
        vals = [0, vmax / 2, vmax]
        return [(v, f"{v:.2f}" if vmax <= 1 else f"{round(v)}") for v in vals]
    for v, text in ticks(left_max):
        pc.create_line(x0, scaler(left_max)(v), x1, scaler(left_max)(v), fill="light grey")
        pc.create_text(x0 - 4, scaler(left_max)(v), text=text, anchor="e", fill=left_color, font=("TkDefaultFont", 9))
    if right_max is not None:
        for v, text in ticks(right_max):
            pc.create_text(x1 + 4, scaler(right_max)(v), text=text, anchor="w", fill=right_color, font=("TkDefaultFont", 9))
    pc.create_rectangle(x0, y0, x1, y1, outline="grey")
    pc.create_text((x0 + x1) // 2, h - 6, text=f"timestep (0 to {n - 1})", font=("TkDefaultFont", 9))
    return sx, scaler(left_max), (scaler(right_max) if right_max is not None else None), x0

def plot_legend(pc, x, series, y=11):
    for color, name in series:
        pc.create_line(x, y, x + 18, y, fill=color, width=2)
        pc.create_text(x + 22, y, text=name, anchor="w", font=("TkDefaultFont", 9))
        x += 22 + 7 * len(name) + 14

def plot_series(pc, sx, sy, values, color, width=1):
    if len(values) > 1:
        pc.create_line(*[c for t, v in enumerate(values) for c in (sx(t), sy(v))], fill=color, width=width)

def draw_plot():
    # Two time-series plots under the pond, redrawn every step.
    n = max(len(model.history), max_timesteps + 1)
    hist = model.history

    # Plot 1: the three source-1 shares (0 to 1), like the duck-distribution plot in 02b
    plot.delete("all")
    sx, sy, _, x0 = plot_axes(plot, n, 1.0)
    plot_series(plot, sx, sy, [r[2] for r in hist], "red")
    plot_series(plot, sx, sy, [r[1] for r in hist], "dark blue")
    plot_series(plot, sx, sy, [r[0] for r in hist], "black", width=2)
    plot_legend(plot, x0, [("red", "prevalence, source 1"), ("dark blue", "prefer source 1"), ("black", "nearer source 1")])

    # Plot 2: untouched food morsels and midline crossings per step (left axis) and
    # cumulative midline crossings (right axis); the cumulative count has a very
    # different range from the other two, so it gets its own axis
    plot2.delete("all")
    food = [r[3] for r in hist]
    crossings = [r[4] for r in hist]
    step_crossings = [r[5] for r in hist]
    left_max = max(1, max(food, default=1), max(step_crossings, default=1))
    cross_max = max(1, max(crossings, default=1))
    sx, sy_left, sy_right, x0 = plot_axes(plot2, n, left_max, cross_max, left_color="dark orange", right_color="purple", top=34)
    plot_series(plot2, sx, sy_left, food, "dark orange", width=2)
    plot_series(plot2, sx, sy_left, step_crossings, "dark green", width=1)
    plot_series(plot2, sx, sy_right, crossings, "purple", width=2)
    plot_legend(plot2, x0, [("dark orange", "untouched food (left)"), ("dark green", "crossings per step (left)")], y=11)
    plot_legend(plot2, x0, [("purple", "cumulative crossings (right)")], y=23)

OUTPUT_DIR = "duck_runs"  # where the batch figures and data files go (next to the notebook)
batch_running = False
batch_cancel = False

def batch_parameters():
    # Everything the model reads, captured once for the file names and the CSV header
    return dict(ducks=duck_slider.get(), pond_width=width_slider.get(), pond_height=height_slider.get(),
                rate1=rate1_slider.get(), size1=size1_slider.get(), rate2=rate2_slider.get(), size2=size2_slider.get(),
                food_pct_width=food_width_slider.get(), food_pct_height=food_height_slider.get(),
                switchiness_mean=sw_mean_slider.get(), switchiness_sd=sw_sd_slider.get(),
                representational=representational_toggle.get(), food_takes_time=food_takes_time_toggle.get(),
                keep_heading=keep_heading_toggle.get(), timesteps=time_slider.get())

def batch_name(p, n):
    return (f"ducks{p['ducks']}_rate{p['rate1']}-{p['rate2']}_size{p['size1']}-{p['size2']}"
            f"_sw{p['switchiness_mean']}-{p['switchiness_sd']}_rep{p['representational']}_ftt{p['food_takes_time']}"
            f"_kh{p['keep_heading']}_pond{p['pond_width']}x{p['pond_height']}_food{p['food_pct_width']}x{p['food_pct_height']}"
            f"_T{p['timesteps']}_n{n}")

def set_controls_state(state):
    # Freeze (or unfreeze) every control except the batch button while a batch runs, so the
    # parameters cannot change part way through
    def walk(widget):
        for child in widget.winfo_children():
            if isinstance(child, (tk.Scale, tk.Checkbutton, tk.Entry, tk.Button)) and child is not batch_button:
                child.config(state=state)
            walk(child)
    walk(frame_sliders)
    walk(frame_buttons)

def repeat_and_graph():
    # Run 'Graph repetitions' simulations with the current parameters (different random seeds), then
    # save a two-panel figure of the means with standard-error ribbons plus a CSV of every
    # run, and show the figure in a new window. Clicking the button again cancels.
    global batch_running, batch_cancel, paused
    if batch_running:
        batch_cancel = True
        return
    params = batch_parameters()
    n, T = repeats_slider.get(), params['timesteps']
    base = get_seed()
    seeds = [base + k for k in range(n)] if base is not None else [random.randrange(1_000_000) for _ in range(n)]

    paused = True
    pause_button.config(text="\u25b6")
    batch_running, batch_cancel = True, False
    set_controls_state("disabled")
    label_timestep.config(text=f"Running {n} simulations of {T} timesteps...")
    runs = []
    t_start = time.time()
    for k, seed in enumerate(seeds):
        m = new_model(seed)
        for t in range(T):
            m.step()
            if t % 20 == 0:
                done = k * T + t + 1
                eta = (time.time() - t_start) / done * (n * T - done)
                batch_button.config(text=f"Cancel  (run {k + 1}/{n}, ~{eta:.0f} s left)")
                root.update()
                if batch_cancel:
                    break
        if batch_cancel:
            break
        runs.append(m.history)
    set_controls_state("normal")
    batch_button.config(text="Repeat and graph")
    batch_running = False
    if batch_cancel or not runs:
        label_timestep.config(text="Batch cancelled; nothing saved.")
        return
    try:
        png_path, csv_path = save_batch(params, seeds[:len(runs)], runs)
    except Exception as e:  # e.g., matplotlib not installed
        label_timestep.config(text=f"Could not save the batch: {e}")
        return
    label_timestep.config(text=f"Saved {os.path.basename(png_path)} and .csv in {OUTPUT_DIR}/")
    show_image(png_path)

def save_batch(params, seeds, runs):
    import numpy as np
    from matplotlib.figure import Figure
    from matplotlib.backends.backend_agg import FigureCanvasAgg

    os.makedirs(OUTPUT_DIR, exist_ok=True)
    n = len(runs)
    name = batch_name(params, n)
    png_path = os.path.join(OUTPUT_DIR, name + ".png")
    csv_path = os.path.join(OUTPUT_DIR, name + ".csv")

    # --- data: one row per run per timestep; parameters as comment lines at the top
    columns = ["run", "seed", "timestep", "nearer_source1", "prefer_source1", "prevalence_source1", "untouched_food", "midline_crossings", "crossings_this_step"]
    with open(csv_path, "w", newline="") as f:
        f.write(f"# Duck Pond Simulation batch, saved {datetime.datetime.now():%Y-%m-%d %H:%M}\n")
        for key, value in params.items():
            f.write(f"# {key}: {value}\n")
        f.write("# nearer_source1 / prefer_source1 / prevalence_source1 are proportions (0-1); midline_crossings is cumulative, crossings_this_step is per timestep\n")
        writer = csv.writer(f)
        writer.writerow(columns)
        for k, (seed, hist) in enumerate(zip(seeds, runs)):
            for t, rec in enumerate(hist):
                writer.writerow([k, seed, t, f"{rec[0]:.4f}", f"{rec[1]:.4f}", f"{rec[2]:.4f}", rec[3], rec[4], rec[5]])

    # --- figure: mean across runs with a +/- 1 standard error ribbon
    arr = np.array(runs, dtype=float)              # shape: runs x timesteps x 6
    mean = arr.mean(axis=0)
    se = arr.std(axis=0, ddof=1) / np.sqrt(n) if n > 1 else np.zeros_like(mean)
    t = np.arange(arr.shape[1])
    fig = Figure(figsize=(9, 7.5), dpi=100)
    FigureCanvasAgg(fig)
    ax1, ax2 = fig.subplots(2, 1, sharex=True)
    for idx, color, label in [(2, "red", "prevalence, source 1"), (1, "darkblue", "prefer source 1"), (0, "black", "nearer source 1")]:
        ax1.plot(t, mean[:, idx], color=color, label=label, linewidth=2 if idx == 0 else 1.2)
        ax1.fill_between(t, mean[:, idx] - se[:, idx], mean[:, idx] + se[:, idx], color=color, alpha=0.2, linewidth=0)
    ax1.set_ylim(0, 1)
    ax1.set_ylabel("proportion")
    ax1.legend(loc="best", fontsize=9)
    mode = "Representational" if params['representational'] else "Nonrepresentational"
    ax1.set_title(f"{n} runs: mean \u00b1 1 standard error\n"
                  f"{mode}; {params['ducks']} ducks; rates {params['rate1']}/{params['rate2']}; sizes {params['size1']}/{params['size2']}; "
                  f"switchiness {params['switchiness_mean']}/{params['switchiness_sd']}; "
                  f"food takes time {params['food_takes_time']}; keep heading {params['keep_heading']}", fontsize=9)
    ax2.plot(t, mean[:, 3], color="darkorange", linewidth=2, label="untouched food (left axis)")
    ax2.fill_between(t, mean[:, 3] - se[:, 3], mean[:, 3] + se[:, 3], color="darkorange", alpha=0.2, linewidth=0)
    ax2.plot(t, mean[:, 5], color="darkgreen", linewidth=1.2, label="midline crossings per step (left axis)")
    ax2.fill_between(t, mean[:, 5] - se[:, 5], mean[:, 5] + se[:, 5], color="darkgreen", alpha=0.2, linewidth=0)
    ax2.set_ylabel("untouched food / crossings per step")
    ax2.set_xlabel("timestep")
    ax2b = ax2.twinx()
    ax2b.plot(t, mean[:, 4], color="purple", linewidth=2, label="cumulative midline crossings (right axis)")
    ax2b.fill_between(t, mean[:, 4] - se[:, 4], mean[:, 4] + se[:, 4], color="purple", alpha=0.2, linewidth=0)
    ax2b.set_ylabel("cumulative midline crossings", color="purple")
    lines = ax2.get_legend_handles_labels()[0] + ax2b.get_legend_handles_labels()[0]
    ax2.legend(lines, [l.get_label() for l in lines], loc="upper left", fontsize=9)
    fig.tight_layout()
    fig.savefig(png_path)
    return png_path, csv_path

def show_image(path):
    # Show a saved PNG in its own window (Tk 8.6 reads PNG directly)
    try:
        win = tk.Toplevel(root)
        win.title(os.path.basename(path))
        img = tk.PhotoImage(file=path)
        lbl = tk.Label(win, image=img)
        lbl.image = img  # keep a reference, or Tk garbage-collects the image
        lbl.pack()
    except tk.TclError as e:
        label_timestep.config(text=f"Saved {path} (could not display it: {e})")

def restart_simulation():
    global model, max_timesteps, paused
    # New model with the current pond size, number of ducks, and random seed (other
    # sliders and the check boxes are read live, so they need no restart). The new
    # simulation waits for the play button.
    max_timesteps = time_slider.get()
    model = new_model(get_seed())
    paused = True
    pause_button.config(text="\u25b6")
    draw_pond()
    schedule_update(speed_slider.get())

paused = True  # the simulation starts when the play button is pressed

root = tk.Tk()
root.title("Duck Pond Simulation")

# Window layout: two columns.
#   Left:  legend, the pond, and the time-series plot under it.
#   Right: buttons, sliders and check boxes, and the readouts under them.
frame_left = tk.Frame(root)
frame_left.pack(side=tk.LEFT, anchor="n", padx=6, pady=6)
frame_right = tk.Frame(root)
frame_right.pack(side=tk.LEFT, anchor="n", padx=6, pady=6)

frame_legend = tk.Frame(frame_left)
frame_legend.pack(side=tk.TOP, anchor="w")
# (the pond canvas and the plot are created below and packed into frame_left after the legend)

frame_buttons = tk.Frame(frame_right)
frame_buttons.pack(side=tk.TOP, anchor="w", pady=(0, 4))
frame_sliders = tk.Frame(frame_right)
frame_sliders.pack(side=tk.TOP, anchor="w")
frame_labels = tk.Frame(frame_right)
frame_labels.pack(side=tk.TOP, anchor="w", pady=(8, 0))

sliderlength = 200

# Timesteps and Number of Ducks
time_slider = tk.Scale(frame_sliders, from_=10, to=1000, label="Max Timesteps", orient=tk.HORIZONTAL, length=sliderlength)
time_slider.grid(row=0, column=0, padx=4)
time_slider.set(200)

duck_slider = tk.Scale(frame_sliders, from_=10, to=200, label="Number of Ducks", orient=tk.HORIZONTAL, length=sliderlength)
duck_slider.grid(row=0, column=1, padx=4)
duck_slider.set(30)

# Pond Height and Pond Width
height_slider = tk.Scale(frame_sliders, from_=20, to=100, label="Pond Height", orient=tk.HORIZONTAL, length=sliderlength)
height_slider.grid(row=1, column=0, padx=4)
height_slider.set(30)

width_slider = tk.Scale(frame_sliders, from_=20, to=100, label="Pond Width", orient=tk.HORIZONTAL, length=sliderlength)
width_slider.grid(row=1, column=1, padx=4)
width_slider.set(30)

# food height and width
food_width_slider = tk.Scale(frame_sliders, from_=10, to=90, label="Food % Width", orient=tk.HORIZONTAL, length=sliderlength)
food_width_slider.grid(row=2, column=0, padx=4)
food_width_slider.set(50)

food_height_slider = tk.Scale(frame_sliders, from_=10, to=50, label="Food % Height", orient=tk.HORIZONTAL, length=sliderlength)
food_height_slider.grid(row=2, column=1, padx=4)
food_height_slider.set(20)


# Rate 1 and Size 1
rate1_slider = tk.Scale(frame_sliders, from_=1, to=20, label="Rate 1 (steps per morsel)", orient=tk.HORIZONTAL, length=sliderlength)
rate1_slider.grid(row=3, column=0, padx=4)
rate1_slider.set(2)

size1_slider = tk.Scale(frame_sliders, from_=1, to=80, label="Size 1", orient=tk.HORIZONTAL, length=sliderlength)
size1_slider.grid(row=3, column=1, padx=4)
size1_slider.set(20)

# Rate 2 and Size 2
rate2_slider = tk.Scale(frame_sliders, from_=1, to=20, label="Rate 2 (steps per morsel)", orient=tk.HORIZONTAL, length=sliderlength)
rate2_slider.grid(row=4, column=0, padx=4)
rate2_slider.set(4)

size2_slider = tk.Scale(frame_sliders, from_=1, to=80, label="Size 2", orient=tk.HORIZONTAL, length=sliderlength)
size2_slider.grid(row=4, column=1, padx=4)
size2_slider.set(20)

# switchiness mean and sd sliders
sw_mean_slider = tk.Scale(frame_sliders, from_=1, to=99, label="Switchiness mean", orient=tk.HORIZONTAL, length=sliderlength)
sw_mean_slider.grid(row=5, column=0, padx=4)
sw_mean_slider.set(5)

sw_sd_slider = tk.Scale(frame_sliders, from_=1, to=99, label="Switchiness standard deviation", orient=tk.HORIZONTAL, length=sliderlength)
sw_sd_slider.grid(row=5, column=1, padx=4)
sw_sd_slider.set(2)

# On/off options, as check boxes. Each is backed by a tk.IntVar (0 or 1) that the
# model reads with .get(), so a change takes effect on the very next step.
representational_toggle = tk.IntVar(value=1)   # ducks track prevalence and choose a preferred source
food_takes_time_toggle  = tk.IntVar(value=0)   # eating a morsel takes 'size' steps instead of 10
keep_heading_toggle     = tk.IntVar(value=0)   # optional movement rule: keep heading when no food is in sight
show_preference_toggle  = tk.IntVar(value=1)   # color ducks by preferred source (dark blue / cyan)
tk.Checkbutton(frame_sliders, text="Representational", variable=representational_toggle).grid(row=8, column=0, sticky="w", padx=4)
tk.Checkbutton(frame_sliders, text="Food takes time",  variable=food_takes_time_toggle).grid(row=8, column=1, sticky="w", padx=4)
tk.Checkbutton(frame_sliders, text="Keep heading",     variable=keep_heading_toggle).grid(row=9, column=0, sticky="w", padx=4)
tk.Checkbutton(frame_sliders, text="Show preference",  variable=show_preference_toggle).grid(row=9, column=1, sticky="w", padx=4)

# Random seed: type an integer to make a run reproducible (applied at Restart);
# leave as None for a different run every time
frame_seed = tk.Frame(frame_sliders)
frame_seed.grid(row=7, column=0, sticky="w", padx=4, pady=(4, 0))
tk.Label(frame_seed, text="Random seed (None=rand):").pack(side=tk.LEFT)
seed_entry = tk.Entry(frame_seed, width=8)
seed_entry.insert(0, "None")
seed_entry.pack(side=tk.LEFT, padx=(4, 0))

# Number of simulations per 'Repeat and graph' batch
repeats_slider = tk.Scale(frame_sliders, from_=2, to=50, label="Graph repetitions", orient=tk.HORIZONTAL, length=sliderlength)
repeats_slider.grid(row=7, column=1, padx=4)
repeats_slider.set(10)


# blocksize multiplier
blocksize_slider = tk.Scale(frame_sliders, from_=5, to=50, label="Image size", orient=tk.HORIZONTAL, length=sliderlength)
blocksize_slider.grid(row=6, column=0, padx=4)
blocksize_slider.set(16)
# animation speed slider
speed_slider = tk.Scale(frame_sliders, from_=5, to=500, label="Delay per step (ms)", orient=tk.HORIZONTAL, length=sliderlength)
speed_slider.grid(row=6, column=1, padx=4)
speed_slider.set(100)


# Buttons, in a row across the top
pause_button = tk.Button(frame_buttons, text="\u25b6", width=3, command=toggle_pause)
pause_button.pack(side=tk.LEFT, padx=(0, 4))
restart_button = tk.Button(frame_buttons, text="Restart", command=restart_simulation)
restart_button.pack(side=tk.LEFT, padx=4)
continue_button = tk.Button(frame_buttons, text="Continue", command=continue_simulation)
continue_button.pack(side=tk.LEFT, padx=4)
batch_button = tk.Button(frame_buttons, text="Repeat and graph", command=repeat_and_graph)
batch_button.pack(side=tk.LEFT, padx=(16, 4))
quit_button = tk.Button(frame_buttons, text="Quit", command=quit_simulation)
quit_button.pack(side=tk.LEFT, padx=4)

# Readouts, below the controls
label_food_prevalence = tk.Label(frame_labels, text="")
label_food_prevalence.grid(row=0, column=0, sticky="w")
label_ducks_nearer = tk.Label(frame_labels, text="")
label_ducks_nearer.grid(row=1, column=0, sticky="w")
label_duck_preference = tk.Label(frame_labels, text="")
label_duck_preference.grid(row=2, column=0, sticky="w")
label_discrepancies = tk.Label(frame_labels, text="")
label_discrepancies.grid(row=3, column=0, sticky="w")
label_check_states = tk.Label(frame_labels, text="")
label_check_states.grid(row=4, column=0, sticky="w")
label_ducks_crossed = tk.Label(frame_labels, text="")
label_ducks_crossed.grid(row=5, column=0, sticky="w")
label_timestep = tk.Label(frame_labels, text="", bg="yellow")
label_timestep.grid(row=6, column=0, sticky="we")

# Color legend, above the pond
for i, (color, meaning) in enumerate([("dark blue", "pref 1"), ("cyan", "pref 2"), ("white", "no pref"), ("orange", "food"), ("red", "eating (fades to white)")]):
    tk.Label(frame_legend, bg=color, width=2, relief=tk.SOLID, borderwidth=1).pack(side=tk.LEFT, padx=(0 if i == 0 else 10, 3))
    tk.Label(frame_legend, text=meaning).pack(side=tk.LEFT)

# Canvas (the pond). Water is the background color; only ducks and food are drawn.
MAX_CANVAS_PX = 800  # the pond is scaled down if it would be bigger than this
model = new_model(get_seed())
max_timesteps = time_slider.get()
canvas = tk.Canvas(frame_left, bg="light blue", width=1, height=1)
canvas.pack(side=tk.TOP, anchor="w", pady=(3, 8))

# Time-series plot, under the pond (its width follows the pond's width)
PLOT_MIN_W, PLOT_H = 380, 170
plot = tk.Canvas(frame_left, bg="white", width=PLOT_MIN_W, height=PLOT_H)
plot.pack(side=tk.TOP, anchor="w")
plot2 = tk.Canvas(frame_left, bg="white", width=PLOT_MIN_W, height=PLOT_H)
plot2.pack(side=tk.TOP, anchor="w", pady=(6, 0))

# Draw the initial state; the animation loop runs but waits (paused) for the play button
draw_pond()
schedule_update(speed_slider.get())

# Start the Tkinter main loop
root.mainloop()

# %% [markdown]
# # Lab report, part 1
#
# First, just explore the simulator. You can control various parameters with the sliders. You may find it helpful to set `Max Timesteps` to a lower value as you explore parameters, but for the runs you report, use at least 300 timesteps so that the distribution has time to settle. Pond height and width, the number of ducks, the switchiness sliders, and the random seed take effect when you click Restart; the other sliders and the check boxes take effect immediately, even during a simulation. *For now, leave the `Representational` box checked and the `Food takes time` and `Keep heading` boxes unchecked.*
#
# Watch single runs first -- seeing the ducks move is the point of an agent-based model. Then, for each condition you report, use *Repeat and graph* (see 'Repeating simulations' above) and give the final mean *Ducks nearer* proportion from the figure, along with what probability matching predicts, and say in a sentence what the top panel looked like (did the black line settle, and where? how wide is the ribbon?). Using the same random seed for the conditions you compare makes the comparisons cleaner. You are welcome to include the saved figures in your report.
#
# 1. Try two rate combinations, keeping both sizes at 20: equal rates (e.g., both 2), and a 2:1 ratio (e.g., rate 1 = 4 and rate 2 = 2). (Remember: 'rate' here is the number of timesteps between morsels, so a *larger* rate means food arrives *less* often. With rate 1 = 4 and rate 2 = 2, Source 2 is the richer source, and probability matching predicts about 1/3 of the ducks nearer Source 1.) If you are curious, also try equal rates at a large value, such as both 8 -- what changes, and what stays the same?
# 2. Try at least three size combinations, keeping both rates at 2: one with equal sizes, one 2:1 (e.g., sizes 20 and 10), and one more extreme (e.g., sizes 20 and 5, a 4:1 ratio). For each, report the final *Ducks nearer* proportions and what probability matching would predict, and add a sentence on what you observed.
# 3. With one interesting combination from #1 or #2, see what happens when you make the pond much taller, say 60 (click Restart after changing the height; the `Image size` slider will help the pond fit on your screen). A single watched run is enough here -- no batch needed. Hint: watch whether the *Ducks nearer* and *Duck preferences* readouts still agree, and think about how long it now takes a duck to cross the pond.
# 4. Draw some general conclusions. This simulation is using the 'representational' approach, where each duck tracks food density over time (size units per time units). Is it able to simulate probability matching due to differences in rate? Is it able to simulate probability matching due to differences in size?

# %% [markdown]
# # Lab report, part 2
#
# We saw that with the 'representational' approach, we seem to be able to do a fine job of simulating probability matching to prevalence differences due to rate or magnitude. Gallistel makes a very strong claim about this approach:
#
# > [Results suggest] that birds accurately represent rates, that they accurately represent morsel magnitudes, and that they can multiply the representation of morsels per unit time by the representation of morsel magnitude to compute the internal variables that determine the relative likelihood of their choosing one foraging patch over the other. (p. 358)
#
# He makes an even bolder claim for alternative theories:
#
# > The challenge for nonrepresentational theories ... is to propound a nonrepresentational model of ... a system that is altered by its past experiences in such a way that it chooses patches in proportion to their relative [densities] ... from ... observations alone ... without the system's having any internal variable[s] ... or a fortiori any operations that appropriately combine these nonexistent representatives of number, time, and magnitude. Is it possible to propound a model of the internal causation of the duck's behavior that avoids postulating an isomorphism between a system of variables and operations inside the duck and the corresponding system of number, time and magnitude external to the duck? (p. 359)
#
# As some of you have noted, his idea of a 'nonrepresentational' account still seems to require a fair amount of representation -- some way of learning which source is 'better' without explicitly tracking rate and size. However, can we make a more radically nonrepresentational version of our model? The way the code works is that when the `Representational` box is checked, there is a step where each duck chooses its preferred source based on food prevalence (rule 1 above). Then it 'aims' for the closest morsel of uneaten food at its preferred source (rule 2).
#
# Well, what would happen if we just skipped the 'choose preferred source' step, and each duck just aimed for the closest morsel of food, no matter which source it is near? Would we still be able to observe probability matching?
#
# First, uncheck the `Representational` box. This skips the 'choose the preferred source' step. Confirm that the readouts on the right show 'Representational: 0'.
#
# 5. Try the same two rate combinations you used for #1 (equal rates, and 2:1), keeping both sizes at 20, so that you can compare the two modes directly.
# 6. Try the same 3 (or more) size combinations you used for #2, keeping both rates at 2. For each, report the final *Ducks nearer* proportions next to what you found in #2, and add a sentence on what you observed.
# 7. Draw some general conclusions. This simulation is using the '**non**representational' approach, where ducks do **not** track food density over time (size units per time units). Is it able to simulate probability matching due to differences in rate? Is it able to simulate probability matching due to differences in size?
#
# # Lab report, part 3
#
# Hint: you should have trouble seeing probability matching based on size when Representational is off.
#
# 8. Why do the Representational and Nonrepresentational modes differ for size?
# 9. Before looking ahead, can you think of any way you could make both modes capable of simulating probability matching based on size differences?
#
# Now keep Representational off and check "Food takes time". When 'Food takes time' is off, it takes a duck 10 timesteps to consume a morsel, no matter what the magnitude (size) value is. (You could change this to a different fixed value by searching the code for `self.stay_time = 10` and `self.initial_stay_time = 10` and changing both.) When 'Food takes time' is on, it takes a duck `size` timesteps to eat a morsel of food (e.g., if `size1` is set to 20, when a duck reaches that morsel, it will stay stationary for 20 timesteps and then it will be free to seek more food). The effect of this switch on size differences is real but small -- too small to see reliably in a single run -- so for #11 and #12 use *Repeat and graph* with the same seed for the on/off comparison and at least 400 timesteps, and compare the outcomes.
#
# 10. How might turning 'Food takes time' on change aspects of the simulation?
# 11. With 'Representational' off and 'Food takes time' on, repeat your size comparisons from #6. What changes do you observe? Is it more like what you observed for #2 or for #6? The effect may be small: can you explain why there is any effect at all, and why it is not larger?
# 12. Now turn 'Representational' back on (leaving 'Food takes time' on), and repeat the size comparisons once more. What changes do you observe compared to #2? Is it better, worse, or just the same? Can you explain why?
#
# 13. How much time did it take you to complete this homework up to this point?
#
# # Lab report, part 4 -- challenge questions
#
# `Honors and graduate students: do at least one of these. Other students may do one for 1% extra credit (see the syllabus).`
#
# **Choose at least one but do as many as you like!**
#
# 14. *Simulation challenge.* Examine how number of ducks relates to rate and magnitude. With the default parameters, what happens if you have only very few ducks or many more than the default? Can you describe 'boundary conditions' on the simulation -- that is, are there particular (approximate) ratios of number of ducks and food prevalence that could help you estimate how many ducks you need at minimum to observe probability matching (for representational and/or nonrepresentational mode)?
# 15. *Simulation challenge.* Another possibility might be that you would find that ducks probability match in the representational mode even when there is 'too much' or 'too little' food for probability matching to emerge with the nonrepresentational mode. What kinds of testable predictions (i.e., predictions you could test with real ducks) might that suggest?
# 16. *Programming / theoretical challenge.* Examine the code where switchiness comes into play (rule 1: the probability that a duck reconsiders on a given timestep). In Gallistel's model the switchiness constant $c$ is the sum of the rates of switching *to* the two patches, so the ratio of time spent in the two patches matches prevalence whatever $c$ is. Does our version seem like an adequate analog to what Gallistel describes? (If your answer is simply 'yes', that's fine, but then don't bother with this question!) If not, can you propose an alternative way to implement switchiness? Double bonus: modify the code to implement your proposal and compare it to the original code (to do this, save a copy of the notebook with a new name where you can introduce your modifications).
# 17. *Simulation / theoretical challenge.* Check 'Keep heading' and compare runs with the switchiness mean set to 5, 20, and 50 (click Restart after each change, because ducks are given their switchiness when they are created). At low switchiness the *Ducks nearer* and *Duck preferences* readouts agree; at high switchiness they come apart. Explain why, from the movement rules. What does this tell you about something the equation model in notebook 02b leaves out?
# 18. *Data analysis challenge.* *Repeat and graph* saves a CSV of every run in `duck_runs/`. In a new notebook, load one or more of these files (`pandas.read_csv(path, comment='#')`) and go beyond the saved figure. For example: plot the *distribution* of the final *nearer_source1* values across the runs (how much do individual runs differ from the mean?); plot the discrepancy from prevalence over time; or combine several batches into a single plot of final proportion against the prevalence ratio, and see how close the points come to the probability-matching line.
# 19. *Programming / theoretical challenge.* The ducks take turns in a random order each timestep (see *How the simulation works*). Rewrite the model so that all ducks decide at the same time from the same view of the pond and then all move at once (mesa's `SimultaneousActivation` scheduler gives each agent a `step()` to decide and an `advance()` to act). What tie-breaking rules did you have to add -- what happens when two ducks want the same cell, or are both next to the same morsel, or one wants the cell another is leaving? Does anything about the results change? (Huberman & Glance, 1993, *PNAS*, showed that for some spatial models the choice between synchronous and asynchronous updating changes the results dramatically.)
